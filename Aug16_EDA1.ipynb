# %%
# Importing important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the data
df=pd.read_csv('zwigato.csv',encoding='latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# Getting columns
print(df.columns)
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# Getting an idea of duplicates in the dataset
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# np.int64(0) means that there are no duplicates in the data.

# %%
# Getting an idea about the data type of the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
'''
From the output of the above code, we can say that
all the columns are in correct data types.
'''
# Out:
# '\nFrom the output of the above code, we can say that\nall the columns are in correct data types.\n'

# %%
#Getting an idea about shape of the data
print('Shape:',df.shape)
print('Rows:',df.shape[0])
print('Columns:',df.shape[1])
# Out:
# Shape: (9551, 21)
# Rows: 9551
# Columns: 21

# %%
'''
There are 9551 rows and 21 columns in the dataset.
'''

# %%
#Statistical data
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
'''
Conclusions ->
(1) From the above output for "Average Cost for two", we can say that
the range of values is from 0 to 8,00,000 and mean is far greater than
median implying that there are outliers in right tail.
(2) From the above output for "Aggregate rating", we can say that
the range of values is from 0.0 to 4.9 and mean is far less than
median implying that there are outliers in left tail.
(3) From the above output for "Votes", we can say that the
range of values is from 0 to 10,934 and mean is far greater than
median implying that there are outliers in right tail.
'''

# %%
#Getting an idea about the NULL values
df.isnull().sum().any()
# Out:
# np.True_

# %%
# np.True_ means that there are NULL values in the dataset.

# %%
# Getting column wise sum of NULL values

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# 'Cuisines' column is having 9 NULL values

# %%
9/9551 * 100
# Out:
# 0.09423097057899697

# %%
'''
   We are having only 0.094% missing values in the data.

There are 3 ways to deal with this issue ->
(1) Remove the rows with NULL values
(2) Impute the rows with missing values
(3) Do nothing

   Since, the proportion of missing data is small, we can remove it.
'''
# Out:
# '\n   We are having only 0.094% missing values in the data.\n   Since, the proportion of missing data is small, we can remove it.\n'

# %%
# Removing rows with missing values
df.dropna(inplace=True)

# %%
# Getting an idea about the NULL values
df.isnull().sum().any()
# Out:
# np.False_

# %%
# np.False_ means that there are no NULL values in the dataset now.

# %%
# Importing the country code dataset
df_country = pd.read_excel('Country-Code.xlsx')
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
# Getting the final dataframe
final_df = df.merge(df_country, on='Country Code', how='left')
final_df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#  how='left' : keeping all columns on left

# %%
#Getting column names
print(final_df.columns)
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
# Getting proportion of values from country column
final_df['Country'].value_counts()
# Out:
# Country
# India             8652
# United States      425
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64

# %%
# Data Visualization ->

# %%
'''
Question ->
Try to plot the pie chart for top 3 countries having
the highest number of restaurants in the given dataset.
'''
# Solution
country_names = final_df['Country'].value_counts().sort_values(ascending = False)[:3].index
country_values = final_df['Country'].value_counts().sort_values(ascending = False)[:3].values

#Plot
plt.figure(figsize=(7,7))
plt.pie(country_values,labels=country_names,autopct='%2f%%',shadow='True')
plt.title('Top 3 country having highest number of restaurants')
plt.legend()
plt.show()

# %%
'''
Conclusions ->
(1) Majority of the restaurents are from India
(2) USA and UK are followed by that having around 4.64% and 0.87% restaurents.
'''

# %%
#Ratings
ratings=final_df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
ratings.head()
# Out:
#    Aggregate rating Rating color Rating text  Rating Count
# 0               0.0        White   Not rated          2148
# 1               1.8          Red        Poor             1
# 2               1.9          Red        Poor             2
# 3               2.0          Red        Poor             7
# 4               2.1          Red        Poor            15

# %%
#Bar plot
plt.figure(figsize=(15,5))
sns.barplot(x='Aggregate rating',y='Rating Count',data=ratings)
plt.title('Count of Aggregate Ratings')
plt.show()

# %%
# Bar Plot
plt.figure(figsize=(15,5))
sns.barplot(x='Aggregate rating',y='Rating Count',hue='Rating color',palette=['blue','red','orange','yellow','green','black'],data=ratings)
plt.title('Count of Aggregate Ratings')
plt.show()

# %%
"""
   Conclusions ->
   Apart from '0.0 Aggregate Rating' the bar graph is following a bell shaped plot
"""

# %%
# Count Plot
plt.figure(figsize=(15,5))
sns.countplot(x='Rating color',data=ratings,palette=['blue','red','orange','yellow','green','black'])
plt.title('Count of Aggregate Ratings')
plt.show()

# %%
'''
   Conclusions ->
   Orange is the highest followed by Red and Yellow, Green, Dark Green and last is White
'''

# %%
# Finding the proportion of countries that have given 0 ratings
final_df[final_df['Rating color']=='White'].groupby('Country').size().reset_index().rename(columns={0:'Frequency'})
# Out:
#           Country  Frequency
# 0          Brazil          5
# 1           India       2139
# 2  United Kingdom          1
# 3   United States          3

# %%
# Question: Draw bar chart and pie chart for the above data
# Solution
country_names = ['Brazil','India','United Kingdom','United States']
frequency_values = [5,2139,1,3]

#Plot
plt.figure(figsize=(7,7))
plt.pie(frequency_values,labels=country_names,autopct='%2f%%',shadow='True')
plt.title('Proportion of countries that have given 0 ratings')
plt.legend()
plt.show()

#Plot
plt.figure(figsize=(12,12))
sns.barplot(x=country_names,y=frequency_values)
plt.title('Proportion of countries that have given 0 ratings')
plt.show()

# %%
'''
Conclusions: India is the major contributor to 0 ratings, and the other countries’ contributions are negligible.
'''

# %%
# Aggregate Rating Wise Country Wise Frequency
final_df.groupby(['Aggregate rating', 'Country']).size().reset_index().rename(columns = {0 : 'Frequency'}).head()
# Out:
#    Aggregate rating         Country  Frequency
# 0               0.0          Brazil          5
# 1               0.0           India       2139
# 2               0.0  United Kingdom          1
# 3               0.0   United States          3
# 4               1.8           India          1

# %%
'''
Question: -> Try to draw clustered bar plot from the above data
'''
# Solution:
df= final_df.groupby(['Aggregate rating', 'Country']).size().reset_index().rename(columns = {0 : 'Frequency'}).head()
sns.barplot(x = 'Country', y = 'Aggregate rating',data=df,hue='Frequency')
plt.title('Aggregate Rating Wise Country Wise Frequency')
plt.show()

# %%
'''
   The dataset is heavily skewed towards India, especially for 0.0 aggregate ratings.
'''

# %%
# Countries focusing on online deliveries
final_df[final_df['Has Online delivery'] == 'Yes'].groupby('Country').size().reset_index().rename(columns = {0 : 'Frequency'})
# Out:
#   Country  Frequency
# 0   India       2423
# 1     UAE         28

# %%
'''
Question: Draw a pie chart for the above data
'''
#Solution->
country_names = ['India','UAE']
frequency_values = [2423,28]

#Plot
plt.figure(figsize=(7,7))
plt.pie(frequency_values,labels=country_names,autopct='%2f%%',shadow='True')
plt.title('Countries focusing on online deliveries')
plt.legend()
plt.show()

# %%
'''
Conclusion: Online deliveries are primarily concentrated in India, with UAE playing only a very small role.
'''

# %%
#Pie Chart for top 5 cities
city_values = final_df['City'].value_counts().sort_values(ascending=False)[:5].values
city_index = final_df['City'].value_counts().sort_values(ascending=False)[:5].index

#Plot
plt.figure(figsize=(9,9))
plt.pie(city_values,labels=city_index,autopct='%2f%%',shadow='True')
plt.title('Top 5 cities having highest number of restaurants')
plt.legend()
plt.show()

# %%
'''
Conclusion: New Delhi dominates the restaurant scene, followed by Gurgaon and Noida, while Faridabad and Ghaziabad contribute very little.
'''
